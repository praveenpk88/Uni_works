# %% [markdown]
# # Practical exercise 1: Data Types

# %% [markdown]
# ## String operations (special characters, concatenation)

# %%
# Run the following code: 

my_string = 'Don\'t mess with' + " lfrit"
print(my_string)
# Out:
# Don't mess with lfrit

# %%
# Re-enter the first line of code (In [1]), after removing the \, and check the output. 
# Now, try to assign the string value in In [1] using double quotes, and check the output. How has the behaviour changed? 
my_string = "Don't mess with" + " lfrit"
print(my_string)
# Out:
# Don't mess with lfrit

# %% [markdown]
# ## Operations on incompatible types

# %%
a = 1 # define a variable 'a'
type(a) # return the type of 'a', the last line of cells will be printed even if without calling print() function
# Out:
# int

# %%
b = 2
print(type(b))
print(a + b) # you can add two numbers
# Out:
# <class 'int'>
# 3

# %%
c = 'two'
print(type(c))
print(a + c) # you will get a 'TypeError' since adding a number and a string is not supported in Python
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 c = 'two'
#       2 print(type(c))
# ----> 3 print(a + c) # you will get a 'TypeError' since adding a number and a string is not supported in Python
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
d = "five"
c + d # this line will be executed correctly, since both c and d are strings. The '+' here will concatenate two strings together.
# Out:
# 'twofive'

# %%
c + " " + d + " twelve" # variable c, [space], variable d, [space]twelve will be concatenated together.
# Out:
# 'two five twelve'

# %% [markdown]
# # Practical exercise 2: Retrieving Data
# “Predicting the age of abalone from physical measurements. The age of abalone is
# determined by cutting the shell through the cone, staining it, and counting the number of
# rings through a microscope -- a boring and time-consuming task. Other measurements,
# which are easier to obtain, are used to predict the age. Further information, such as weather
# patterns and location (hence food availability) may be required to solve the problem.”

# %%
import pandas as pd # import pandas package and define a nickname 'pd' for convenience

# %%
# Load a csv file from the web (you can use either the following ‘online’ or ‘offline’ method to load the data) 

# online
abalone_p = "https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data"

# Read a comma-separated values (csv) file from a URL into DataFrame.
# Please understand how read_csv() works via:
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html#pandas.read_csv
abalone = pd.read_csv(abalone_p, sep=',', decimal='.', header=None, 
                      names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 
                             'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'])
abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
# offline
# 1. Download the abalone dataset from Canvas → Modules → Week 3
# 2. Move the file to your home directory next to your jupyter notebook 
abalone_p = 'abalone.data.csv'

# Read a local comma-separated values (csv) file into DataFrame.
# Please understand how read_csv() works via:
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html#pandas.read_csv
abalone = pd.read_csv(abalone_p, sep=',', decimal='.', header=None, 
                      names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 
                             'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'])
abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# ## Check the types of loaded columns

# %%
# Return the dtypes (Data Types) in the DataFrame.
# Please understand 'dtypes' via:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dtypes.html
abalone.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %% [markdown]
# ## Print the first n rows

# %%
# Return the first n rows.
# Please understand how head() works via:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html

abalone.head(2)
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
#
#    Shell weight  Rings
# 0          0.15     15
# 1          0.07      7

# %% [markdown]
# ## Get the names of columns

# %%
# The column labels of the DataFrame.
abalone.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %% [markdown]
# ## Extract n columns

# %%
# Extract the column named 'Rings', return a Series Object, of which the first column is "Index", 
# the second column is values of the corresponding column 'Rings'
y = abalone['Rings'] 
y
# Out:
# 0       15
# 1        7
# 2        9
# 3       10
# 4        7
#         ..
# 4172    11
# 4173    10
# 4174     9
# 4175    10
# 4176    12
# Name: Rings, Length: 4177, dtype: int64

# %%
# Extract multiple columns ['Sex', 'Diameter'] at once, return a DataFrame Object, 
# of which the first column is "Index" as well.

X = abalone[['Sex', 'Diameter']]
X
# Out:
#      Sex  Diameter
# 0      M     0.365
# 1      M     0.265
# 2      F     0.420
# 3      M     0.365
# 4      I     0.255
# ...   ..       ...
# 4172   F     0.450
# 4173   M     0.440
# 4174   M     0.475
# 4175   F     0.485
# 4176   M     0.555
#
# [4177 rows x 2 columns]

# %% [markdown]
# ## Size of the dataset (X, y)

# %%
y.shape # Return a tuple of the shape of the underlying data.
# Out:
# (4177,)

# %%
X.shape # Return a tuple representing the dimensionality of the DataFrame.
# Out:
# (4177, 2)

# %% [markdown]
# ## Generate frequency table for Rings values

# %%
# Return a Series containing counts of unique values.
# Please understand value_counts() of Series via:
# https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html

y.value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 24      2
# 27      2
# 1       1
# 25      1
# 2       1
# 26      1
# 29      1
# Name: Rings, dtype: int64

# %% [markdown]
# ## Create a DataFrame by customized data

# %%
# Create two-dimensional, size-mutable, potentially heterogeneous tabular data by yourself.
# Please understand how pd.DataFrame works via:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# {'key1': [], 'key2': [], ...} is a dictionary in Python
df1 = pd.DataFrame({'name': ['Jason', 'Lucy', 'Helen'], 'height': [180, 170, 165], 'weight': [75, 65, 72]}) 
df1
# Out:
#     name  height  weight
# 0  Jason     180      75
# 1   Lucy     170      65
# 2  Helen     165      72

# %%
df2 = pd.DataFrame({'name': ['Jason', 'Lucy', 'Helen'], 'mathematics': [80, 90, 65], 'science': [75, 65, 72]})
df2
# Out:
#     name  mathematics  science
# 0  Jason           80       75
# 1   Lucy           90       65
# 2  Helen           65       72

# %%
df3 = pd.DataFrame({'name': ['Jason', 'Lucy', 'Helen'], 'company': ['RMIT', 'RMIT', 'RMIT'], 'salary': [100000, '120,000', '110,000']})
df3
# Out:
#     name company   salary
# 0  Jason    RMIT   100000
# 1   Lucy    RMIT  120,000
# 2  Helen    RMIT  110,000

# %%
df4 = pd.DataFrame({'name': ['Jason', 'Lucy', 'Helen'], '# of attendance': [22, 22, 15]})
df4
# Out:
#     name  # of attendance
# 0  Jason               22
# 1   Lucy               22
# 2  Helen               15

# %% [markdown]
# ## Merge different DataFrames by 'name'

# %%
# Merge DataFrame or named Series objects with a database-style join.
# Please understand how merge() function works via:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.merge.html#pandas.DataFrame.merge

merged_df = df1.merge(df2, on='name', how='inner')
merged_df = merged_df.merge(df3, on='name', how='inner')
merged_df = merged_df.merge(df4, on='name', how='inner')
merged_df
# Out:
#     name  height  weight  mathematics  science company   salary  \
# 0  Jason     180      75           80       75    RMIT   100000
# 1   Lucy     170      65           90       65    RMIT  120,000
# 2  Helen     165      72           65       72    RMIT  110,000
#
#    # of attendance
# 0               22
# 1               22
# 2               15

# %%
# Use Method Chain

merged_df = df1.merge(df2, on='name', how='inner').merge(df3, on='name', how='inner').merge(df4, on='name', how='inner')
merged_df
# Out:
#     name  height  weight  mathematics  science company   salary  \
# 0  Jason     180      75           80       75    RMIT   100000
# 1   Lucy     170      65           90       65    RMIT  120,000
# 2  Helen     165      72           65       72    RMIT  110,000
#
#    # of attendance
# 0               22
# 1               22
# 2               15

# %%
# Use For loop

all_df = [df2, df3, df4]
merged_df = df1
for df in all_df:
    merged_df = merged_df.merge(df, on='name', how='inner')
merged_df
# Out:
#     name  height  weight  mathematics  science company   salary  \
# 0  Jason     180      75           80       75    RMIT   100000
# 1   Lucy     170      65           90       65    RMIT  120,000
# 2  Helen     165      72           65       72    RMIT  110,000
#
#    # of attendance
# 0               22
# 1               22
# 2               15

# %% [markdown]
# # Practical Exercise 3: Data Preparation

# %% [markdown]
# ## Copy the Abalone dataset

# %%
# Make a copy of this object’s indices and data.
# Please understand the copy() function via:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.copy.html

fake_abalone = abalone.copy()
fake_abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# ## Add redundant whitespaces

# %%
# Access a group of rows and columns by label(s) or a boolean array.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html

fake_abalone.loc[fake_abalone.Rings.isin([1, 2, 3]), 'Sex'] = 'I '
fake_abalone['Sex'].value_counts()
# Out:
# M     1525
# I     1328
# F     1307
# I       17
# Name: Sex, dtype: int64

# %% [markdown]
# ## Remove redundant whitespaces

# %%
# Remove leading and trailing characters.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.Series.str.strip.html

fake_abalone['Sex'] = fake_abalone['Sex'].str.strip()
fake_abalone['Sex'].value_counts()
# Out:
# M    1525
# I    1345
# F    1307
# Name: Sex, dtype: int64

# %% [markdown]
# ## Replace ‘I’ (Infant) labels with ‘K’ (Kid)

# %%
# Replace values given in to_replace with value.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.Series.replace.html

fake_abalone['Sex'].replace('I', 'K', inplace=True) 
fake_abalone
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      K   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %% [markdown]
# ## Inject NaN (Not a Number) data

# %%
print(fake_abalone[['Diameter', 'Rings']][fake_abalone.Rings == 22])

# Inject NaN data to the column 'Diameter' when fake_abalone.Rings == 22
fake_abalone.loc[fake_abalone.Rings == 22, 'Diameter'] = float('NaN') 

print(fake_abalone[['Diameter', 'Rings']][fake_abalone.Rings == 22])
# Out:
#      Diameter  Rings
# 232     0.505     22
# 270     0.525     22
# 275     0.540     22
# 351     0.450     22
# 433     0.420     22
# 675     0.395     22
#      Diameter  Rings
# 232       NaN     22
# 270       NaN     22
# 275       NaN     22
# 351       NaN     22
# 433       NaN     22
# 675       NaN     22

# %% [markdown]
# ## Drop missing data

# %%
# Remove missing values.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html

fake_abalone = fake_abalone.dropna()
print(fake_abalone[['Diameter', 'Rings']][fake_abalone.Rings == 22])
# Out:
# Empty DataFrame
# Columns: [Diameter, Rings]
# Index: []

# %% [markdown]
# ## Inject again

# %%
fake_abalone = abalone.copy()

print(fake_abalone[['Diameter', 'Rings']][fake_abalone.Rings == 22])
fake_abalone.loc[fake_abalone.Rings == 22, 'Diameter'] = float('NaN')
print(fake_abalone[['Diameter', 'Rings']][fake_abalone.Rings == 22])
# Out:
#      Diameter  Rings
# 232     0.505     22
# 270     0.525     22
# 275     0.540     22
# 351     0.450     22
# 433     0.420     22
# 675     0.395     22
#      Diameter  Rings
# 232       NaN     22
# 270       NaN     22
# 275       NaN     22
# 351       NaN     22
# 433       NaN     22
# 675       NaN     22

# %% [markdown]
# ## Replace missing data with more meaningful values (negative constant, mean and median)

# %%
# Fill NA/NaN values using the specified method.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html

# pandas.Series.mean: Return the mean of the values over the requested axis.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.Series.mean.html

fake_abalone['Diameter'].fillna(fake_abalone['Diameter'].mean(axis=0), inplace=True)
fake_abalone[['Diameter', 'Rings']][fake_abalone.Rings == 22]
# Out:
#      Diameter  Rings
# 232  0.407788     22
# 270  0.407788     22
# 275  0.407788     22
# 351  0.407788     22
# 433  0.407788     22
# 675  0.407788     22

# %% [markdown]
# ## Add new observation to merged_df

# %%
merged_df
# Out:
#     name  height  weight  mathematics  science company   salary  \
# 0  Jason     180      75           80       75    RMIT   100000
# 1   Lucy     170      65           90       65    RMIT  120,000
# 2  Helen     165      72           65       72    RMIT  110,000
#
#    # of attendance
# 0               22
# 1               22
# 2               15

# %%
# A part of Helen's attendance is recorded into another dataset, which needs to be added to merged_df
# Please refer to the doc of append() method: 
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.append.html

merged_df = merged_df.append({'name': 'Helen', 'height': 165, 'weight': 72, 'mathematics': 65, 
                              'science': 72, 'company': 'RMIT', 
                              'salary': '110,000', '# of attendance': 6}, ignore_index=True)
merged_df
# Out:
#     name  height  weight  mathematics  science company   salary  \
# 0  Jason     180      75           80       75    RMIT   100000
# 1   Lucy     170      65           90       65    RMIT  120,000
# 2  Helen     165      72           65       72    RMIT  110,000
# 3  Helen     165      72           65       72    RMIT  110,000
#
#    # of attendance
# 0               22
# 1               22
# 2               15
# 3                6

# %% [markdown]
# ## The rows with index 2 and 3 are recorded separately for the same staff, which needs to merge to one row.

# %%
# groupby(): Group DataFrame using a mapper or by a Series of columns.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html

# transform(): Call function producing a like-indexed Series on each group and return a Series 
# having the same indexes as the original object filled with the transformed values.
# Please refer to: 
# https://pandas.pydata.org/docs/reference/api/pandas.core.groupby.SeriesGroupBy.transform.html

merged_df['# of attendance'] = merged_df.groupby(['name', 'height', 'weight', 'mathematics', 'science', 
                                                  'company', 'salary'])['# of attendance'].transform('sum') # use the return values of sum() function as the transformed values
merged_df['# of attendance']
# Out:
# 0    22
# 1    22
# 2    21
# 3    21
# Name: # of attendance, dtype: int64

# %% [markdown]
# ## Remove duplicates

# %%
merged_df
# Out:
#     name  height  weight  mathematics  science company   salary  \
# 0  Jason     180      75           80       75    RMIT   100000
# 1   Lucy     170      65           90       65    RMIT  120,000
# 2  Helen     165      72           65       72    RMIT  110,000
# 3  Helen     165      72           65       72    RMIT  110,000
#
#    # of attendance
# 0               22
# 1               22
# 2               21
# 3               21

# %%
# Return DataFrame with duplicate rows removed.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

merged_df = merged_df.drop_duplicates(subset=['name', 'height', 'weight', 'mathematics', 'science', 
                                              'company', 'salary']).reset_index(drop=True)
merged_df
# Out:
#     name  height  weight  mathematics  science company   salary  \
# 0  Jason     180      75           80       75    RMIT   100000
# 1   Lucy     170      65           90       65    RMIT  120,000
# 2  Helen     165      72           65       72    RMIT  110,000
#
#    # of attendance
# 0               22
# 1               22
# 2               21

# %% [markdown]
# ## Transfer 'salary' to numbers

# %%
# Use astype to transform data type
# astype(): Cast a pandas object to a specified dtype dtype.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.Series.astype.html

# str.replace(): Replace each occurrence of pattern/regex in the Series/Index.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.Series.str.replace.html

merged_df['salary'] = merged_df['salary'].astype('str').str.replace(',', '').astype('int')
merged_df
# Out:
#     name  height  weight  mathematics  science company  salary  \
# 0  Jason     180      75           80       75    RMIT  100000
# 1   Lucy     170      65           90       65    RMIT  120000
# 2  Helen     165      72           65       72    RMIT  110000
#
#    # of attendance
# 0               22
# 1               22
# 2               21

# %%
# Or use pd.to_numeric
# Convert argument to a numeric type.
# Please refer to: https://pandas.pydata.org/docs/reference/api/pandas.to_numeric.html

merged_df['salary'] = pd.to_numeric(merged_df['salary'].astype('str').str.replace(',', ''))
merged_df
# Out:
#     name  height  weight  mathematics  science company  salary  \
# 0  Jason     180      75           80       75    RMIT  100000
# 1   Lucy     170      65           90       65    RMIT  120000
# 2  Helen     165      72           65       72    RMIT  110000
#
#    # of attendance
# 0               22
# 1               22
# 2               21

# %% [markdown]
# # Advanced Exercise: Dealing with big datasets
# Please don’t try this exercise until you are done with all the previous. ;-)

# %% [markdown]
# ## Re-load the abalone file from the web

# %%
abalone_p = "https://archive.ics.uci.edu/ml/machine-learning-databases/abalone/abalone.data"

# %%
'''
Load the dataset in chunks of the same size; each chunk is a piece of the dataset that contains all 
the columns and the number of lines set in the function call (the chunksize parameter). 
'''

abalone_chunks = pd.read_csv(abalone_p, sep=',', decimal='.', header=None, 
                             names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 
                                    'Shucked weight', 'Viscera weight', 'Shell weight',  'Rings'],  
                             chunksize=10)

# %%
'''
Note that the output of the read_csv function in this case is not a pandas DataFrame but an 
iterator-like object. In fact, to get the results, you need to iterate that object. 
'''

for chunk in abalone_chunks:
    print(chunk.shape)
    print(chunk)
# Out:
# (10, 9)
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5   I   0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6   F   0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7   F   0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8   M   0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9   F   0.550     0.440   0.150        0.8945          0.3145          0.1510
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# ...

# %%
'''
Load the dataset by specifically asking for an iterator of it. In this case, you can decide 
dynamically the length (that is, how many lines) you want for each piece of the pandas DataFrame. 
'''

abalone_iterator = pd.read_csv(abalone_p, sep=',', decimal='.', header=None, 
                               names=['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 
                                      'Shucked weight', 'Viscera weight', 'Shell weight', 'Rings'],  
                               iterator=True)

# %% [markdown]
# ## Read a piece of data with 10 lines.

# %%
# Please refer to: https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-chunking
abalone_iterator.get_chunk(10).shape
# Out:
# (10, 9)

# %% [markdown]
# ## Read further 20 rows.

# %%
abalone_iterator.get_chunk(20).shape
# Out:
# (20, 9)

# %% [markdown]
# ## Finally, read two further rows, save in a variable and print it.

# %%
piece = abalone_iterator.get_chunk(2)
print(piece)
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 30   M    0.58      0.47   0.165        0.9975          0.3935
# 31   F    0.68      0.56   0.165        1.6390          0.6055
#
#     Viscera weight  Shell weight  Rings
# 30          0.2420          0.33     10
# 31          0.2805          0.46     15
