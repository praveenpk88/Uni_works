# %% [markdown]
# #            Regular Expression (Marked Exercise 15% - Group Dummy)
# ----------------------------------------------------------------------------------------------------------
#
#
# This marked exercise is weights 15% of your total mark. In this exercise, you have 3 question and 40 minues to answer them.
#
# ----------------------------------------------------------------------------------------------------------
#
# #### You will save the functions mentioned in this notebook in a separate python file, named after your group and student number (groupNumber_sNumber.py-'s' small) e.g., "group1_s123456.py". Failing to save the file in the given format will incur 0 marks, as automated marking will be used to assess the assessment. Sample content of the file be will as follow:

# %%
#Note: the code within the methods can be modified by the students. The name of the method SHOULD NOT be changed. 
#The input and output of the methods should satisfy the criteria mentioned in the tasks
import re

def task1(test_string):
    #this is dummy code and could be replaced with your actual code
    out=re.fullmatch(r'', test_string)
    if out==test_string:
        return 1
    else:
        return 0

def task2(test_string):
    #this is dummy code and could be replaced with your actual code
    out=re.fullmatch(r'', test_string)
    if out==test_string:
        return out
    else:
        return ' '

def task3(test_string):
    #this is dummy code and could be replaced with your actual code
    out=re.fullmatch(r'', test_string)

    return out

# %% [markdown]
# ####   Hard coding any part of the task(s) is not allowed. This include using `|` to simply concatenate the full text of all the matched cases. This will result in '0' mark for the task(s)
#
# Tasks 1-2 will be assessed against 5 test cases, 1 mark for each case
#
# Task 3 will be assessed against 3 test cases, 5/3=1.67 mark for each case
#
# #### Note: The test cases can contain one token/word or multiple words. The hard contrainst (e.g., location, number, presence or absence of characters) are explicitly mentioned in the tasks, which should be considered while writing the regex expressions.  ALL THE BEST!
#
# Note: Special characters list for this assessment include =  + ; : @ _ # %

# %% [markdown]
# ### Dummy Task1  (total marks = 5)
#
#
#
# #### Write a regex pattern to match tokens or words satisfying the following format of a pdf document: `dataset_Number.pdf` (starting with "dataset" keyword, followed by an underscore '\_' and number(s) ONLY) e.g., "dataset_01.pdf" or "dataset_2018.pdf" should be matched by the regular expression. The following tokens should be skipped by the regular expression  ['dataset_01.pdf.tmp', 'file_10.pdf', 'dataser12.pdf'] The test cases will contain a list of one word/token e.g., `['dataset_01.pdf.tmp', 'file_10.pdf', 'dataser12.pdf','dataset_01.pdf', 'dataset_2018.pdf']`.
#
# The method should return '1' if there is a match, else it should return '0'

# %%
def task1(test_string):
    #this is dummy code and could be replaced with your actual code
    out=re.fullmatch(r'', test_string)
    if out==test_string:
        return 1
    else:
        return 0

# %% [markdown]
# ### Dummy Task2 (total marks = 5)
#
# #### Note: The output of the method will be the string that satisfies the constraints else if should output empty string
#
# e.g.
#      `out=re.fullmatch(r'', test_string)
#       if out==test_string:
#          return out
#       else:
#          return ' '`
#
# Write a regular expression that finds the valid the state and postcode form the Austrlian address. \
# The format is in the following format: **State (short form) 4-digit postcode Australia (seperated by spaces)**
# e.g.,
# - VIC 3000 Australia
# - NSW 2000 Asutralia
# - ACT 2601 Australia
#
# Following formats should be ignored by the regex:
# - 3000 VIC Australia
# - VIC-3000, Australia
# - VIC3000, Australia

# %%
def task2(test_string):
    #this is dummy code and could be replaced with your actual code
    out=re.fullmatch(r'', test_string)
    if out==test_string:
        return out
    else:
        return ' '
